# %%
from pathlib import Path
import pandas as pd
from ydata_profiling import ProfileReport
RAW = Path("..//data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
PROCESSED = Path("..//data/processed/telco_churn_clean.csv")
if PROCESSED.exists():
    df = pd.read_csv(PROCESSED)
else:
    df = pd.read_csv(RAW)
    df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
    df = df.dropna(subset=["TotalCharges"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
#       2 import pandas as pd
# ----> 3 from ydata_profiling import ProfileReport
#       4 RAW = Path("..//data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
#       5 PROCESSED = Path("..//data/processed/telco_churn_clean.csv")
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
profile = ProfileReport(df, title="Telco Churn YData Profile", explorative=True)
Path("reports").mkdir(parents=True, exist_ok=True)
profile.to_file("reports/telco_churn_ydata_profile.html")

# %%
profile
